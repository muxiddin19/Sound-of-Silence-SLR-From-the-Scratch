# %%
import pickle
import torch
import cv2
def read_pkl(path):
    with open(path, 'rb') as f:
        data1 = pickle.load(f)
    return data1
path ='/nas/Dataset/Phoenix/phoenix-2014-keypoints.pkl'
data = read_pkl(path)

# %%
len(data)
# Out:
# 6841

# %% [markdown]
# ## Visualization image with the related keypoints

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a function to load the image data for each frame
def load_image(frame_index):
    # Replace with your image loading logic
    image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
    #print('Image path-', image_path) 
    return cv2.imread(image_path)

# ... (load keypoints data as before)

# Iterate through each video
for video_key, video_data in data.items():
    #print('Video key ', video_key)
    keypoints = video_data['keypoints']
    #print
    #keys = video_key['']

    # Iterate through each frame
    for frame_index, frame_keypoints in enumerate(keypoints):
        #print('Frame index ', frame_index)
        frame_image = load_image(frame_index)  # Load the corresponding image

        # Convert BGR (OpenCV format) to RGB (Matplotlib format) if needed
        frame_image = cv2.cvtColor(frame_image, cv2.COLOR_BGR2RGB)

        # Plot the image
        if (video_key == "fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute") & (frame_index < 10) :
            plt.imshow(frame_image)

            # Plot the keypoints
            #plt.scatter(frame_keypoints[:, 0], frame_keypoints[:, 1], color='red', s=5)
            plt.scatter(frame_keypoints[:, 0], frame_keypoints[:, 1], color='red', s=5)

            plt.title(f"Frame {frame_index}")
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-c0a76082a66c> in <module>
#      22     for frame_index, frame_keypoints in enumerate(keypoints):
#      23         #print('Frame index ', frame_index)
# ---> 24         frame_image = load_image(frame_index)  # Load the corresponding image
#      25
#      26         # Convert BGR (OpenCV format) to RGB (Matplotlib format) if needed
#
# <ipython-input-37-c0a76082a66c> in load_image(frame_index)
#       8     image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
#       9     #print('Image path-', image_path)
# ---> 10     return cv2.imread(image_path)
#      11
#      12 # ... (load keypoints data as before)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualizing only image data

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a function to load the image data for each frame
def load_image(frame_index):
    # Replace with your image loading logic
    image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
    #print('Image path-', image_path) 
    return cv2.imread(image_path)

# ... (load keypoints data as before)

# Iterate through each video
for video_key, video_data in data.items():
    #print('Video key ', video_key)
    keypoints = video_data['keypoints']
    #print
    #keys = video_key['']

    # Iterate through each frame
    for frame_index, frame_keypoints in enumerate(keypoints):
        #print('Frame index ', frame_index)
        frame_image = load_image(frame_index)  # Load the corresponding image

        # Convert BGR (OpenCV format) to RGB (Matplotlib format) if needed
        frame_image = cv2.cvtColor(frame_image, cv2.COLOR_BGR2RGB)

        # Plot the image
        if (video_key == "fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute") & (frame_index < 10) :
            plt.imshow(frame_image)

            # Plot the keypoints
            #plt.scatter(frame_keypoints[:, 0], frame_keypoints[:, 1], color='red', s=5)
            #plt.scatter(frame_keypoints[:, 0], frame_keypoints[:, 1], color='red', s=5)

            plt.title(f"Frame {frame_index}")
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-da1dbdb08299> in <module>
#      22     for frame_index, frame_keypoints in enumerate(keypoints):
#      23         #print('Frame index ', frame_index)
# ---> 24         frame_image = load_image(frame_index)  # Load the corresponding image
#      25
#      26         # Convert BGR (OpenCV format) to RGB (Matplotlib format) if needed
#
# <ipython-input-31-da1dbdb08299> in load_image(frame_index)
#       8     image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
#       9     #print('Image path-', image_path)
# ---> 10     return cv2.imread(image_path)
#      11
#      12 # ... (load keypoints data as before)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Visualizing only keypoint data

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a function to load the image data for each frame
def load_image(frame_index):
    # Replace with your image loading logic
    image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
    #print('Image path-', image_path) 
    return cv2.imread(image_path)

# ... (load keypoints data as before)

# Iterate through each video
for video_key, video_data in data.items():
    #print('Video key ', video_key)
    keypoints = video_data['keypoints']
    #print
    #keys = video_key['']

    # Iterate through each frame
    for frame_index, frame_keypoints in enumerate(keypoints):
        #print('Frame index ', frame_index)
        frame_image = load_image(frame_index)  # Load the corresponding image

        # Convert BGR (OpenCV format) to RGB (Matplotlib format) if needed
        frame_image = cv2.cvtColor(frame_image, cv2.COLOR_BGR2RGB)

        # Plot the image
        if (video_key == "fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute") & (frame_index < 10) :
            #plt.imshow(frame_image)

            # Flip y-coordinate for Matplotlib visualization
            frame_keypoints[:, 1] = frame_image.shape[0] - frame_keypoints[:, 1]

            # Plot the keypoints
            #plt.scatter(frame_keypoints[:, 0], frame_keypoints[:, 1], color='red', s=5)
            plt.scatter(frame_keypoints[:, 0], frame_keypoints[:, 1], color='red', s=5)

            plt.title(f"Frame {frame_index}")
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-71a7b8eb743e> in <module>
#      22     for frame_index, frame_keypoints in enumerate(keypoints):
#      23         #print('Frame index ', frame_index)
# ---> 24         frame_image = load_image(frame_index)  # Load the corresponding image
#      25
#      26         # Convert BGR (OpenCV format) to RGB (Matplotlib format) if needed
#
# <ipython-input-38-71a7b8eb743e> in load_image(frame_index)
#       8     image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
#       9     #print('Image path-', image_path)
# ---> 10     return cv2.imread(image_path)
#      11
#      12 # ... (load keypoints data as before)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Getting Doppler data

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have a function to load the image data for each frame
def load_image(frame_index):
    # Replace with your image loading logic
    image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
    #print('Image path-', image_path) 
    return cv2.imread(image_path)

# ... (load keypoints data as before)

# Iterate through each video
for video_key, video_data in data.items():
    #print('Video key ', video_key)
    keypoints = video_data['keypoints']
    #print
    #keys = video_key['']

    # Iterate through each frame
    for frame_index, frame_keypoints in enumerate(keypoints):
        #print('Frame index ', frame_index)
        frame_image = load_image(frame_index)  # Load the corresponding image

        # Convert BGR (OpenCV format) to RGB (Matplotlib format) if needed
        frame_image = cv2.cvtColor(frame_image, cv2.COLOR_BGR2RGB)

        # Plot the image
        if (video_key == "fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute") & (frame_index < 10) :
            plt.imshow(frame_image)

            # Plot the keypoints
            #plt.scatter(frame_keypoints[:, 0], frame_keypoints[:, 1], color='red', s=5)
            plt.scatter(frame_keypoints[:, 0], frame_keypoints[:, 1], color='red', s=5)

            plt.title(f"Frame {frame_index}")
            plt.show()

# %%
def load_image(video_key, frame_index):
    # Replace with your image loading logic
    image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
    image = cv2.imread(image_path)
    return image

# ... (load keypoints data as before)

# Iterate through each video
for video_key, video_data in data.items():
    print('Video key ', video_key)
    keypoints = video_data['keypoints']

    # Iterate through each frame
    for frame_index, frame_keypoints in enumerate(keypoints):
        print('Frame index ', frame_index)
        frame_image = load_image(video_key, frame_index)  # Load the corresponding image

        # Convert to PyTorch tensor and move to GPU
        frame_image_tensor = torch.from_numpy(frame_image.transpose(2, 0, 1)).float().to('cuda')

        # ... (process frame_image_tensor and keypoints using GPU)

# %%
import cv2
import numpy as np

# Assuming you have a function to load the image data for each frame
def load_image(frame_index, video_key):
    # Replace with your image loading logic using OpenCV-DNN
    image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
    print('Image path-', image_path)
    
    # Check if GPU is available
    if cv2.cuda.getCudaEnabledDeviceCount() > 0:
        # Load the image using OpenCV DNN with GPU backend
        net = cv2.dnn.readNetFromCaffe("path/to/deploy.prototxt", "path/to/weights.caffemodel")
        blob = cv2.dnn.blobFromImage(image_path, 1.0, (224, 224), (104.0, 177.0, 123.0))
        net.setInput(blob)
        # Assuming the network outputs the image
        image = net.forward()[:, 0, :, :]  # Extract the image from the output
        image = image.transpose(1, 2, 0)  # Change channel order if needed
    else:
        # Fallback to CPU if GPU is not available
        image = cv2.imread(image_path)

    return image

# ... (load keypoints data as before)

# Iterate through each video
for video_key, video_data in data.items():
    print('Video key ', video_key)
    keypoints = video_data['keypoints']

    # Iterate through each frame
    for frame_index in range(0, 177):  # Adjust the range as needed
        print('Frame index ', frame_index)
        frame_image = load_image(frame_index, video_key)  # Load the corresponding image

        # Rest of the code (converting to RGB, plotting image and keypoints) remains the same

# %%
import pickle
import cv2
import torch

def read_pkl(path):
    with open(path, 'rb') as f:
        data = pickle.load(f)
    return data

def load_image(video_key, frame_index):
    # Replace with your image loading logic
    image_path = f"/nas/Dataset/Phoenix/phoenix2014-release/phoenix-2014-multisigner/features/{video_key}.avi_pid0_fn000{frame_index:03d}-0.png"  # Adjust the path
    image = cv2.imread(image_path)
    return image

# ... (load keypoints data as before)

# Iterate through each video
for video_key, video_data in data.items():
    print('Video key ', video_key)
    keypoints = video_data['keypoints']

    # Iterate through each frame
    for frame_index, frame_keypoints in enumerate(keypoints):
        print('Frame index ', frame_index)
        frame_image = load_image(video_key, frame_index)  # Load the corresponding image

        # Convert to PyTorch tensor and move to GPU
        frame_image_tensor = torch.from_numpy(frame_image.transpose(2, 0, 1)).float().to('cuda')

        # ... (process frame_image_tensor and keypoints using GPU)
