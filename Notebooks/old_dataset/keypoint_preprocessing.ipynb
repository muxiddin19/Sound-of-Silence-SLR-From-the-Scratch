# %%
import pickle 
def read_pkl(path):
    with open(path, 'rb') as f:
        data1 = pickle.load(f)
    return data1
path = r'/nas/Dataset/Phoenix/phoenix-2014-keypoints.pkl'
data = read_pkl(path)
data
# Out:
# {'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute': {'keypoints': array([[[109.4   ,  48.53  ,   0.9727],
#           [118.    ,  41.22  ,   0.9795],
#           [ 99.06  ,  43.    ,   0.985 ],
#           ...,
#           [101.44  , 243.4   ,   0.828 ],
#           [106.6   , 245.8   ,   0.8804],
#           [110.1   , 246.6   ,   0.8843]],
#
#          [[108.6   ,  47.16  ,   0.966 ],
#           [117.9   ,  40.2   ,   0.9604],
#           [ 98.7   ,  41.8   ,   0.9736],
#           ...,
#           [103.    , 239.6   ,   0.842 ],
#           [106.8   , 241.5   ,   0.8643],
#           [109.25  , 242.2   ,   0.848 ]],
#
#          [[108.    ,  46.28  ,   0.9556],
#           [117.56  ,  39.7   ,   0.9785],
#           [ 98.06  ,  40.66  ,   0.9683],
#           ...,
#           [ 99.    , 227.6   ,   0.7515],
#           [102.1   , 230.5   ,   0.813 ],
#           [104.06  , 231.9   ,   0.8125]],
#
#          ...,
#
# ...

# %%
type(data)
# Out:
# dict

# %%
len(data)
# Out:
# 6841

# %%
data.keys()
# Out:
# dict_keys(['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute', 'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-2/1/01April_2010_Thursday_heute', 'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-3/1/01April_2010_Thursday_heute', 'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-4/1/01April_2010_Thursday_heute', 'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-6/1/01April_2010_Thursday_heute', 'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-7/1/01April_2010_Thursday_heute', 'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-8/1/01April_2010_Thursday_heute', 'fullFrame-210x260px/train/01April_2010_Thursday_tagesschau_default-0/1/01April_2010_Thursday_tagesschau', 'fullFrame-210x260px/train/01April_2010_Thursday_tagesschau_default-2/1/01April_2010_Thursday_tagesschau', 'fullFrame-210x260px/train/01April_2010_Thursday_tagesschau_default-3/1/01April_2010_Thursday_
# ...

# %%
len(data.keys())
# Out:
# 6841

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']
# Out:
# {'keypoints': array([[[109.4   ,  48.53  ,   0.9727],
#          [118.    ,  41.22  ,   0.9795],
#          [ 99.06  ,  43.    ,   0.985 ],
#          ...,
#          [101.44  , 243.4   ,   0.828 ],
#          [106.6   , 245.8   ,   0.8804],
#          [110.1   , 246.6   ,   0.8843]],
#
#         [[108.6   ,  47.16  ,   0.966 ],
#          [117.9   ,  40.2   ,   0.9604],
#          [ 98.7   ,  41.8   ,   0.9736],
#          ...,
#          [103.    , 239.6   ,   0.842 ],
#          [106.8   , 241.5   ,   0.8643],
#          [109.25  , 242.2   ,   0.848 ]],
#
#         [[108.    ,  46.28  ,   0.9556],
#          [117.56  ,  39.7   ,   0.9785],
#          [ 98.06  ,  40.66  ,   0.9683],
#          ...,
#          [ 99.    , 227.6   ,   0.7515],
#          [102.1   , 230.5   ,   0.813 ],
#          [104.06  , 231.9   ,   0.8125]],
#
#         ...,
#
#         [[101.75  ,  65.1   ,   0.935 ],
#          [110.2   ,  51.34  ,   0.971 ],
#          [ 89.9   ,  53.56  ,   0.959 ],
# ...

# %%
len(data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'])
# Out:
# 176

# %%
len(data.values())
# Out:
# 6841

# %%
len(data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute'])
# Out:
# 1

# %%
import pandas as pd
pd1 = pd.DataFrame(data)
pd1
# Out:
#           fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute  \
# keypoints  [[[109.4, 48.53, 0.9727], [118.0, 41.22, 0.979...
#
#           fullFrame-210x260px/train/01April_2010_Thursday_heute_default-2/1/01April_2010_Thursday_heute  \
# keypoints  [[[102.9, 58.34, 0.959], [113.06, 47.47, 0.957...
#
#           fullFrame-210x260px/train/01April_2010_Thursday_heute_default-3/1/01April_2010_Thursday_heute  \
# keypoints  [[[92.75, 62.1, 0.947], [100.9, 46.62, 0.969],...
#
#           fullFrame-210x260px/train/01April_2010_Thursday_heute_default-4/1/01April_2010_Thursday_heute  \
# keypoints  [[[90.25, 62.16, 0.9717], [99.06, 48.28, 0.944...
#
#           fullFrame-210x260px/train/01April_2010_Thursday_heute_default-6/1/01April_2010_Thursday_heute  \
# keypoints  [[[95.7, 53.94, 0.9536], [104.94, 42.66, 0.96]...
#
#           fullFrame-210x260px/train/01April_2010_Thursday_heute_default-7/1/01April_2010_Thursday_heute  \
# ...

# %%
#keys = data.keys()
#keys={}
import pandas as pd
for key in data.keys():
    #part = key.split(',')
    #print(part)
    #keys[key] = part
    pd1 = pd.DataFrame(data)
    pd1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 8
#       3 import pandas as pd
#       4 for key in data.keys():
#       5     #part = key.split(',')
#       6     #print(part)
#       7     #keys[key] = part
# ----> 8     pd1 = pd.DataFrame(data)
#       9     pd1
#
# File ~/miniconda3/envs/yolov8-env/lib/python3.8/site-packages/pandas/core/frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 709     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     710 elif isinstance(data, ma.MaskedArray):
#     711     from numpy.ma import mrecords
#
# ...

# %%
keys
# Out:
# {'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute': ['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute'],
#  'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-2/1/01April_2010_Thursday_heute': ['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-2/1/01April_2010_Thursday_heute'],
#  'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-3/1/01April_2010_Thursday_heute': ['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-3/1/01April_2010_Thursday_heute'],
#  'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-4/1/01April_2010_Thursday_heute': ['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-4/1/01April_2010_Thursday_heute'],
#  'fullFrame-210x260px/train/01April_2010_Thursday_heute_default-6/1/01April_2010_Thursday_heute': ['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-6/1/01April_2010_Thursday_heute'],
# ...

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints']
# Out:
# array([[[109.4   ,  48.53  ,   0.9727],
#         [118.    ,  41.22  ,   0.9795],
#         [ 99.06  ,  43.    ,   0.985 ],
#         ...,
#         [101.44  , 243.4   ,   0.828 ],
#         [106.6   , 245.8   ,   0.8804],
#         [110.1   , 246.6   ,   0.8843]],
#
#        [[108.6   ,  47.16  ,   0.966 ],
#         [117.9   ,  40.2   ,   0.9604],
#         [ 98.7   ,  41.8   ,   0.9736],
#         ...,
#         [103.    , 239.6   ,   0.842 ],
#         [106.8   , 241.5   ,   0.8643],
#         [109.25  , 242.2   ,   0.848 ]],
#
#        [[108.    ,  46.28  ,   0.9556],
#         [117.56  ,  39.7   ,   0.9785],
#         [ 98.06  ,  40.66  ,   0.9683],
#         ...,
#         [ 99.    , 227.6   ,   0.7515],
#         [102.1   , 230.5   ,   0.813 ],
#         [104.06  , 231.9   ,   0.8125]],
#
#        ...,
#
#        [[101.75  ,  65.1   ,   0.935 ],
#         [110.2   ,  51.34  ,   0.971 ],
#         [ 89.9   ,  53.56  ,   0.959 ],
#         ...,
# ...

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute'].keys()
# Out:
# dict_keys(['keypoints'])

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute'].values()
# Out:
# dict_values([array([[[109.4   ,  48.53  ,   0.9727],
#         [118.    ,  41.22  ,   0.9795],
#         [ 99.06  ,  43.    ,   0.985 ],
#         ...,
#         [101.44  , 243.4   ,   0.828 ],
#         [106.6   , 245.8   ,   0.8804],
#         [110.1   , 246.6   ,   0.8843]],
#
#        [[108.6   ,  47.16  ,   0.966 ],
#         [117.9   ,  40.2   ,   0.9604],
#         [ 98.7   ,  41.8   ,   0.9736],
#         ...,
#         [103.    , 239.6   ,   0.842 ],
#         [106.8   , 241.5   ,   0.8643],
#         [109.25  , 242.2   ,   0.848 ]],
#
#        [[108.    ,  46.28  ,   0.9556],
#         [117.56  ,  39.7   ,   0.9785],
#         [ 98.06  ,  40.66  ,   0.9683],
#         ...,
#         [ 99.    , 227.6   ,   0.7515],
#         [102.1   , 230.5   ,   0.813 ],
#         [104.06  , 231.9   ,   0.8125]],
#
#        ...,
#
#        [[101.75  ,  65.1   ,   0.935 ],
#         [110.2   ,  51.34  ,   0.971 ],
#         [ 89.9   ,  53.56  ,   0.959 ],
#         ...,
# ...

# %%
type(data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute'].values())
# Out:
# dict_values

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints']
# Out:
# array([[[109.4   ,  48.53  ,   0.9727],
#         [118.    ,  41.22  ,   0.9795],
#         [ 99.06  ,  43.    ,   0.985 ],
#         ...,
#         [101.44  , 243.4   ,   0.828 ],
#         [106.6   , 245.8   ,   0.8804],
#         [110.1   , 246.6   ,   0.8843]],
#
#        [[108.6   ,  47.16  ,   0.966 ],
#         [117.9   ,  40.2   ,   0.9604],
#         [ 98.7   ,  41.8   ,   0.9736],
#         ...,
#         [103.    , 239.6   ,   0.842 ],
#         [106.8   , 241.5   ,   0.8643],
#         [109.25  , 242.2   ,   0.848 ]],
#
#        [[108.    ,  46.28  ,   0.9556],
#         [117.56  ,  39.7   ,   0.9785],
#         [ 98.06  ,  40.66  ,   0.9683],
#         ...,
#         [ 99.    , 227.6   ,   0.7515],
#         [102.1   , 230.5   ,   0.813 ],
#         [104.06  , 231.9   ,   0.8125]],
#
#        ...,
#
#        [[101.75  ,  65.1   ,   0.935 ],
#         [110.2   ,  51.34  ,   0.971 ],
#         [ 89.9   ,  53.56  ,   0.959 ],
#         ...,
# ...

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'].shape
# Out:
# (176, 133, 3)

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'][0]
# Out:
# array([[1.0938e+02, 4.8531e+01, 9.7266e-01],
#        [1.1800e+02, 4.1219e+01, 9.7949e-01],
#        [9.9062e+01, 4.3000e+01, 9.8486e-01],
#        [1.2988e+02, 4.9188e+01, 8.9648e-01],
#        [8.8062e+01, 5.3625e+01, 8.8525e-01],
#        [1.5500e+02, 1.1512e+02, 8.7744e-01],
#        [6.6938e+01, 1.1838e+02, 8.6328e-01],
#        [1.7938e+02, 1.9888e+02, 8.0566e-01],
#        [4.2719e+01, 2.0688e+02, 8.1543e-01],
#        [1.5900e+02, 2.1812e+02, 9.3945e-01],
#        [8.0250e+01, 2.2550e+02, 9.1895e-01],
#        [1.4550e+02, 2.4550e+02, 7.8027e-01],
#        [8.3688e+01, 2.4662e+02, 8.0273e-01],
#        [1.0556e+02, 7.0812e+01, 1.2134e-01],
#        [9.2500e+01, 5.6625e+01, 1.0779e-01],
#        [1.2925e+02, 2.3325e+02, 2.5146e-01],
#        [8.8000e+01, 4.1469e+01, 3.0273e-01],
#        [1.2850e+02, 2.3162e+02, 4.6387e-01],
#        [1.2875e+02, 2.3188e+02, 4.7510e-01],
#        [1.1844e+02, 2.5212e+02, 3.4741e-01],
#        [1.0106e+02, 2.3875e+02, 4.2236e-01],
# ...

# %%
len(data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'])
# Out:
# 176

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'][0].shape
# Out:
# (133, 3)

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'][0][0]
# Out:
# array([109.4   ,  48.53  ,   0.9727], dtype=float16)

# %%
len(data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_87248\2455707945.py in <module>
# ----> 1 len(data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'][0][0])
#
# NameError: name 'data' is not defined

# %%
data['fullFrame-210x260px/train/01April_2010_Thursday_heute_default-0/1/01April_2010_Thursday_heute']['keypoints'][0][0][0]
# Out:
# 109.4
