# %%
import os
import json
import zipfile
import pickle
import numpy as np
from tempfile import TemporaryDirectory

def process_video_folder(video_folder_path, output_pickle_path):
    """
    Process a single video folder containing JSON files (one per frame).
    Extracts pose keypoints, left hand keypoints, and right hand keypoints and saves them into a pickle file.

    Parameters:
        video_folder_path (str): Path to the folder containing JSON files for one video.
        output_pickle_path (str): Path to save the pickle file for this video.
    """
    all_frames = {
        'pose': [],
        'hand_left': [],
        'hand_right': []
    }
    
    # List and sort all JSON files in the video folder
    json_files = [os.path.join(video_folder_path, f)
                  for f in os.listdir(video_folder_path) if f.endswith('.json')]
    json_files.sort()  # Ensure frames are in order

    for json_file in json_files:
        try:
            with open(json_file, 'r') as f:
                data = json.load(f)
        except json.JSONDecodeError as e:
            print(f"Skipping file {json_file} due to JSON decode error: {e}")
            continue

        # Check if the JSON file contains 'people' data
        if "people" not in data or not data["people"]:
            print(f"Skipping file {json_file} as no people data was found.")
            continue

        # Try to extract and reshape the pose and hand keypoints
        try:
            pose = np.array(data['people']['pose_keypoints_2d']).reshape(-1, 3)
            hand_left = np.array(data['people']['hand_left_keypoints_2d']).reshape(-1, 3)
            hand_right = np.array(data['people']['hand_right_keypoints_2d']).reshape(-1, 3)
        except KeyError as e:
            print(f"Skipping file {json_file} due to missing key: {e}")
            continue
        except Exception as e:
            print(f"Skipping file {json_file} due to error: {e}")
            continue

        all_frames['pose'].append(pose)
        all_frames['hand_left'].append(hand_left)
        all_frames['hand_right'].append(hand_right)

    # If no valid frames were found, skip saving a pickle file for this folder.
    if not all_frames['pose'] or not all_frames['hand_left'] or not all_frames['hand_right']:
        print(f"No valid frames found in folder {video_folder_path}. Skipping saving pickle.")
        return

    # Stack lists into NumPy arrays with shape (frames, keypoints, 3)
    all_frames['pose'] = np.stack(all_frames['pose'], axis=0)
    all_frames['hand_left'] = np.stack(all_frames['hand_left'], axis=0)
    all_frames['hand_right'] = np.stack(all_frames['hand_right'], axis=0)

    # Save the dictionary to a pickle file
    with open(output_pickle_path, 'wb') as f:
        pickle.dump(all_frames, f)

    print(f"Saved: {output_pickle_path}")

def process_all_videos_from_zip(zip_path, output_dir):
    """
    Process all video folders inside a ZIP archive.
    For each video folder, extract pose, left hand, and right hand keypoints from the JSON files 
    and save them to a separate pickle file.

    Parameters:
        zip_path (str): Path to the ZIP file containing the JSON data.
        output_dir (str): Directory where the output pickle files will be saved.
    """
    os.makedirs(output_dir, exist_ok=True)

    # Extract the ZIP file into a temporary directory
    with TemporaryDirectory() as temp_dir:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(temp_dir)

        # Based on the structure: <temp_dir>/01_crowd_keypoint/01/ contains the video folders
        target_dir = os.path.join(temp_dir, "01") #, "01"
        if not os.path.exists(target_dir):
            print(f"Target directory {target_dir} does not exist. Check the ZIP file structure.")
            return

        # List all subdirectories (each representing one video)
        video_folders = [d for d in os.listdir(target_dir)
                         if os.path.isdir(os.path.join(target_dir, d))]
        for video_folder in video_folders:
            video_folder_path = os.path.join(target_dir, video_folder)
            # Save the pickle file with the original video folder name
            output_pickle_path = os.path.join(output_dir, f"{video_folder}.pkl")
            process_video_folder(video_folder_path, output_pickle_path)

# === Example usage ===

zip_file_path = r"/nas/Dataset/KSL/Train/[라벨]01_real_word_keypoint.zip"
output_directory = r"/nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/"

process_all_videos_from_zip(zip_file_path, output_directory)
# Out:
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1417_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1770_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2620_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2174_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2981_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0398_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2583_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1057_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1810_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0015_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2573_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1285_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0809_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2430_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1853_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1199_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1403_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1020_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2779_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2117_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0483_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2346_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2374_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2814_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2556_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2070_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2104_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1551_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0104_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1361_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0851_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2472_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0305_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0036_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2787_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1912_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1025_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2057_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0344_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1369_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2565_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0864_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2261_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0026_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1418_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2442_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0761_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2088_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2449_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0006_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0631_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2653_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1244_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1009_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0281_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0692_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1889_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1621_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1839_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2829_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0316_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0765_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0240_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2824_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2183_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2031_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0741_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0429_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2316_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0339_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0994_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2768_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2897_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1969_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2460_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1904_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0508_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1550_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0712_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2720_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2887_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0259_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2232_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2602_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2189_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1769_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1454_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1557_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0686_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0805_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0931_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1828_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0441_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2214_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0767_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2982_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2525_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2320_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1819_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0299_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0084_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1109_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2086_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2566_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2603_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1296_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0505_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2721_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1338_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1392_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2943_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1592_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0128_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0754_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1325_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1399_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0482_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0736_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0939_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2783_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1013_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1506_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0729_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0523_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0205_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1391_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0940_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0664_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0491_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2955_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1932_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0624_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1734_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2946_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0381_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1570_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1123_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2922_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1377_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1894_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0117_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1258_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2948_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2443_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0195_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1242_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2235_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2154_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1789_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2727_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0282_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0742_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1360_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0517_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0462_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2461_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2121_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0419_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0879_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1937_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0401_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2599_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0097_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2304_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0679_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1642_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0017_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2990_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1024_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1647_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0698_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2630_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2366_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1752_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1977_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0206_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2037_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0136_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1716_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0217_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2172_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2281_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2262_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2008_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0218_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0756_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2480_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2429_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0132_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1888_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0119_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2597_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0972_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0915_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0470_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0334_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1344_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0594_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0415_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1581_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2203_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1387_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0752_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0954_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0816_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0352_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1198_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0085_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2222_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0381_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2206_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2090_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1958_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1103_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2477_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1724_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1340_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1773_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2445_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1636_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1287_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1114_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2972_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1089_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0249_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2741_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1672_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0369_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2207_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2879_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2928_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2781_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1230_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2389_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1054_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2459_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0365_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2887_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1775_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2114_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0155_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0157_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0935_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0651_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0116_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1571_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1314_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0028_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1361_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0366_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2703_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0645_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1655_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0135_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2917_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1972_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0106_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0401_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1717_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0431_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1131_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0938_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0975_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0244_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2562_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0256_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD2963_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0622_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1249_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0433_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0939_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0060_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0068_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1448_REAL01_L.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1817_REAL01_R.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1491_REAL01_F.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD1447_REAL01_U.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD0256_REAL01_D.pkl
# Saved: /nas/Chingiz/sing_language/all_json_to_pkl/01_real_word_keypoint/01/01/NIA_SL_WORD