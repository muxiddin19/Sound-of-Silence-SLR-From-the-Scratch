# %%
import pickle
def read_pkl(path):
    with open(path, 'rb') as f:
        data1 = pickle.load(f)
    return data1

 
path = '/nas/Chingiz/sing_language/all_json_to_pkl/01_crowd_keypoint/01_quantized/NIA_SL_FS0001_CROWD01_F.pkl' # integer points with multi disc

data_vector = read_pkl(path)

# %%
data_vector['hand_right_quantized']
# Out:
# {0: array([[510.35 , 723.023],
#         [390.35 , 733.023],
#         [430.35 , 693.023],
#         [440.35 , 663.023],
#         [450.35 , 663.023],
#         [457.669, 658.023],
#         [460.35 , 663.023],
#         [470.35 , 663.023],
#         [460.35 , 673.023],
#         [470.35 , 673.023],
#         [470.35 , 673.023],
#         [470.35 , 673.023],
#         [470.35 , 673.023],
#         [460.35 , 683.023],
#         [470.35 , 693.023],
#         [480.35 , 713.023],
#         [480.35 , 723.023],
#         [460.35 , 743.023],
#         [430.35 , 763.023],
#         [400.35 , 783.023],
#         [380.35 , 793.023],
#         [380.35 , 783.023],
#         [380.35 , 783.023],
#         [370.35 , 773.023],
#         [380.35 , 783.023],
#         [380.35 , 783.023],
#         [380.35 , 783.023],
#         [390.35 , 763.023],
#         [400.35 , 743.023],
#         [400.35 , 733.023],
#         [410.35 , 723.023],
#         [420.35 , 723.023],
#         [430.35 , 713.023],
# ...
